# %% [markdown]
# # CLASE 3.2: CREACIÓN DE GRÁFICOS TÍPICOS
# ---
#
# ## Gráficos de líneas.
# Quizás el más sencillo de todos los gráficos que podamos realizar mediante el uso de **Matplotlib** corresponda a la visualización de una única función del tipo $y=f(x)$. Este será el primer ejercicio que realicemos oficialmente con esta librería. Para ello, y como en el resto de esta asignatura, inicializaremos nuestro script con el siguiente conjunto de instrucciones (donde intercambiaremos con frecuencia la plantilla de estilos que utilizaremos, a fin de ir acostumbrándonos de a poco a las alternativas que **Matplotlib** nos ofrece):

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Setting de plantilla tipo "bmh".
plt.style.use("bmh")

# %% [markdown]
# Para todos los gráficos que construyamos en **Matplotlib**, en general, siempre comenzaremos creando dos objetos: La **figura** propiamente tal (mediante la función `plt.figure()`), y los *ejes* que corresponderán a las referencias absolutas de nuestro gráfico (mediante la función `plt.axes()`). Siempre podremos controlar la resolución de nuestra figura al definirla, añadiendo el argumento `dpi` a la función `plt.figure()` y un valor numérico que define la correspondiente densidad de puntos por pixel:

# %%
# La figura y los paneles que la limitan (en este caso, sólo uno).
fig = plt.figure(dpi=120)
ax = plt.axes()

# %% [markdown]
# En **Matplotlib**, la *figura* (la instancia que definimos mediante `plt.figure()`) puede ser pensada como un único contenedor que agrupa todos los objetos de Python que representan los ejes, gráficos, texto, anotaciones y etiquetasque están definidas para la imagen correspondiente. La instancia `ax` (resultante de la función `plt.axes()`) es lo que vemos en la imagen presentada en la lámina anterior: Una caja que limita la figura con etiquetas y marcadores (ticks), que eventualmente contendrá los elementos del gráfico que permitirán su visualización, y que puede ser más de uno en el caso de construir una grilla que contenga varios paneles de gráficos. En esta asignatura, en general, siempre referiremos estas instancias a las variables cuyos nombres son `fig` y `ax`, respectivamente.
#
# Por cierto, cuando inicializamos una figura usando la función `plt.figure()`, podemos controlar sus dimensiones mediante el uso del parámetro `figsize`, el cual acepta una tupla con dos números de punto flotante que representan sus dimensiones en una relación de tipo `(largo, alto)`:

# %%
fig = plt.figure(figsize=(8, 4), dpi=120)
ax = plt.axes();

plt.figure(figsize=(5, 5), dpi=120)
ax = plt.axes();

plt.figure(figsize=(3, 7), dpi=120)
ax = plt.axes();

# %% [markdown]
# Una vez creados los ejes, podemos utilizar la función `ax.plot()` para construir un sencillo **gráfico de líneas**. Comencemos pues con una función exponencial, a fin de ilustrar el procedimiento:

# %%
fig = plt.figure(dpi=120) # Inicializamos nuestra figura.
ax = plt.axes() # Inicializamos el panel donde irá nuestro gráfico.
x = np.linspace(0, 3, 1000) # Construimos la data que irá en el eje horizontal.
ax.plot(x, np.exp(x)); # Construimos nuestro gráfico de líneas.

# %% [markdown]
# Alternativamente, podemos utilizar la interfaz tipo Matlab:

# %%
plt.figure(dpi=120) # Inicializamos nuestra figura.
plt.plot(x, np.exp(x)); # Construimos nuestro gráfico de líneas.

# %% [markdown]
# Si queremos crear una única figura con múltiples gráficos de líneas, podemos simplemente llamar la función `plt.plot()` (o el método `plot()`, si usamos la interfaz orientada a objetos) tantas veces como queramos:

# %%
plt.figure(dpi=120) # Inicializamos nuestra figura.
plt.plot(x, x**3 + 2*x**2 - 4*x + 1); # Construimos nuestro primer gráfico de líneas.
plt.plot(x, -2*x**3 - x**2 + x - 3); # Construimos nuestro segundo gráfico de líneas.

# %% [markdown]
# Y eso es todo lo que necesitamos saber para graficar rápidamente funciones en **Matplotlib**. Navegaremos en algunos detalles en breve, acerca de cómo controlar la apariencia de nuestro gráfico, en términos de los ejes y las líneas propiamente tales.
#
# ## Ajuste de colores y estilos.
# El primer ajuste que podríamos querer realizar corresponde al control del color de las líneas y sus estilos. La función `plt.plot()` acepta argumentos adicionales para especificar ambas características de nuestros gráficos. Para ajustar el color, podemos usar el parámetro `color`, el cual acepta un parámetro de tipo string que representa, virtualmente, cualquier color que imaginemos. Y dicho color puede especificarse de una buena cantidad de formas:

# %%
plt.figure(dpi=120) # Inicializamos nuestra figura.
x = np.linspace(start=0.1, stop=5, num=100) # Generamos nuestra data.

# Especificación del color por su nombre
plt.plot(x, np.log(x), color="green")

# Código corto de color, modelo sustractivo (rgbcmyk)
plt.plot(x, np.log(x) + 1, color="m")

# Escala de grises, entre 0 y 1.
plt.plot(x, np.log(x) + 2, color="0.7")

# Código hexadecimal (RRGGBB desde 00 a FF).
plt.plot(x, np.log(x) + 3, color="#FFDD44")

# Tupla RGB (modelo aditivo), valores entre 0 y 1.
plt.plot(x, np.log(x) + 4, color=(1.0, 0.2, 0.3))

# Código HTML de color.
plt.plot(x, np.log(x) + 5, color='chartreuse');

# %% [markdown]
# Si no se especifica ningún color, **Matplotlib** automáticamente ciclará entre una colección de colores por defecto para múltiples líneas en un gráfico, y que son dependientes del tipo de plantilla de estilos que utilicemos. Similarmente, el estilo de la línea puede setearse mediante el parámetro `linestyle`:

# %%
# Definimos la data a graficar en el eje horizontal.
x = np.linspace(start=-2, stop=2, num=100)

# El tipo de línea se especifica mediante el prámetro linestyle.
plt.figure(dpi=120)
plt.plot(x, x**2 + 0, linestyle='solid')
plt.plot(x, x**2 + 1, linestyle='dashed')
plt.plot(x, x**2 + 2, linestyle='dashdot')
plt.plot(x, x**2 + 3, linestyle='dotted')

# El tipo de línea puede especificarse también mediante varios símbolos.
plt.plot(x, x**2 + 4, linestyle='-') # Equivalente a linestyle='solid'.
plt.plot(x, x**2 + 5, linestyle='--') # Equivalente a linestyle='dashed'.
plt.plot(x, x**2 + 6, linestyle='-.') # Equivalente a linestyle='dashdot'.
plt.plot(x, x**2 + 7, linestyle=':'); # Equivalente a linestyle='dotted'.

# %% [markdown]
# O bien, si deseamos compactar aún más nuestro código, podemos escribir:

# %%
# Códigos compactos de línea y color.
plt.figure(dpi=120)
plt.plot(x, x**2 + 0, '-r') # Equivalente a linestyle="-", color="r".
plt.plot(x, x**2 + 1, '--c') # Equivalente a linestyle="--", color="c".
plt.plot(x, x**2 + 2, '-.m') # Equivalente a linestyle="-.", color="m".
plt.plot(x, x**2 + 3, ':g') # Equivalente a linestyle=":", color="g".

# %% [markdown]
# Los caracteres anteriores que permiten especificar los respectivos colores reflejan las abreviaturas de tipo estándar que suelen ser utilizadas en modelos de color típicos en el diseño de elementos gráficos, como es el caso del modelo aditivo (RGB) o sustractivo (CMYK) de colores.
#
# ## Límites de ejes de graficación.
# En general, **Matplotlib** hace un trabajo bastante adecuado escogiendo los límites para los valores mostrados en cada eje de nuestros gráficos. Sin embargo, a veces es bueno tener el control de estos valores. La forma más directa de cambiarlos es mediante el uso de las funciones `plt.xlim()` y `plt.ylim()`, según sea el eje que deseemos intervenir:

# %%
# Límites para los ejes de graficación.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.xlim(-1, 1)
plt.ylim(-1, 1);

# %% [markdown]
# Si, por alguna razón, queremos que los valores mostrados en algún eje se muestren en orden inverso, bastará simplemente con especificar dicho orden en las funciones anteriores. Por ejemplo:

# %%
# Inversión de la dirección del eje horizontal.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.xlim(2, -2);

# %% [markdown]
# Una alternativa al setting anterior podría ser la utilización de la función `plt.axis()`, la que nos permite controlar todos los ejes de un gráfico al mismo tiempo, especificando como argumento una lista con una estructura de tipo `[xmin, xmax, ymin, ymax]`. Por ejemplo:

# %%
# Uso de la función plt.axis() para controlar los límites de un eje.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.axis([-1, 1, -1, 1]);

# %% [markdown]
# La función `plt.axis()` va mucho más allá. También nos permite hacer cosas tales como, automáticamente, ajustar al máximo los bordes de nuestra figura en torno al gráfico respectivo mediante el uso del parámetro `option`:

# %%
# Uso de los tipos de ajuste de ejes.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.axis("equal")
plt.title("equal");

plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.axis("tight")
plt.title("tight");

plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.axis("scaled")
plt.title("scaled");

# %% [markdown]
# ## Rótulos de ejes, título y leyenda de un gráfico.
# Para finalizar nuestros primeros pasos en la graficación con **Matplotlib**, exploraremos brevemente algunas opciones para rotular nuestras figuras. Esto es, agregar títulos a nuestros gráficos, rótulos de ejes y leyendas sencillas.
#
# Los títulos y rótulos de ejes pueden especificar de manera muy sencilla mediante las funciones `plt.title()`, `plt.xlabel()` y `plt.ylabel()`. Tales rótulos son compatibles con código de tipo `TeX`, lo que nos permite incluso escribir ecuaciones o texto con subíndices o superíndices, siempre que permitamos que el intérprete de Python lea los símbolos `\`(*backslash*) de manera literal, lo que puede conseguirse anteponiendo una `r` antes del texto. Cualquier texto en `TeX` debe ir, dentro del string, entre dos símbolos `"$"`. Por ejemplo:

# %%
# Un gráfico con sus rótulos de ejes y su título.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.xlabel("x")
plt.ylabel(r"$x^{2}$")
plt.title(r"La función $y=x^{2}$");

# %% [markdown]
# La posición, tamaño y estilo de los rótulos de eje pueden ser ajustadas mediante varios argumentos. Por ejemplo, el parámetro `fontsize` nos permite especificar el **tamaño de fuente** de nuestro rótulo mediante un valor de tipo entero, mientras que el parámetro `fontweight` nos permite especificar el estilo de dichos rótulos mediante un string. Por ejemplo, `"bold"` para un rótulo en negrita, `"light"` para un estilo más suave. Finalmente, el parámetro `fontstyle` nos permite controlar el estilo de letra entre las opciones `normal` (por defecto) o `italic` (cursiva).
#
# En caso de la dirección de estos rótulos, podemos incluso controlar su rotación respecto de su correspondiente eje de graficación mediante el argumento `rotation` (que es un entero entre 0 y 360, que define el ángulo de rotación), o su espaciamiento del mismo eje mediante `labelpad` (tipo entero):

# %%
# Un gráfico con sus rótulos de ejes y su título. En este caso, los rótulos y el
# título vienen más personalizados.
plt.figure(dpi=120)
plt.plot(x, x**2, color="purple")
plt.xlabel("x", fontsize=12, labelpad=10, fontstyle="oblique")
plt.ylabel(r"$x^{2}$", fontsize=12, labelpad=12, rotation=0)
plt.title(r"La función $y=x^{2}$", fontsize=14, fontweight="bold");

# %% [markdown]
# Cuando se muestran múltiples líneas en un gráfico (o, usando la terminología de **Matplotlib**, en un mismo panel), puede ser útil crear una leyenda que especifique el significado de cada una de esas líneas. Y en este caso, **Matplotlib** también dispone de métodos para mostrar una leyenda en nuestras figuras, por ejemplo, mediante la función `plt.legend()`. Para ello, es necesario especificar además, en el constructor de cada gráfico, el rótulo de cada línea mediante el parámetro `label`, el cual corresponde a un argumento de la función `plt.plot()`:

# %%
# Construcción de una leyenda sencilla.
plt.figure(dpi=120)
x = np.linspace(start=-5, stop=5, num=100)
plt.plot(x, np.sin(x), '-y', label=r'$sen(x)$')
plt.plot(x, np.cos(x), '-.g', label=r'$cos(x)$')
plt.legend();

# %% [markdown]
# Como resulta evidente, la función `plt.legend()` mantiene la trazabilidad tanto de los colores como del estilo de nuestras líneas. Cubriremos algunas opciones un poco más avanzadas a medida que vayamos aprendiendo a construir otros tipos de gráfico y personalizando sus distintos elementos.
#
# ## Equivalencias entre interfaces.
# Mientras que la mayoría de las funciones de `pyplot` tienen métodos equivalentes y con el mismo nombre para el caso de la interfaz orientada a objetos, tales como `plt.plot()` y `ax.plot()`, o bien, `plt.legend()` y `ax.legend()`.
#
# Sin embargo, otras funciones en la interfaz orientada a objetos sufren algunos cambios pequeños al transicionar entre ésta y la interfaz de tipo Matlab. Ejemplos de aquello son las correspondencias mostradas en la Tabla (1.1).
#
# <p style="text-align: center;">Tabla (1.1): Equivalencias entre interfaces de Matplotlib</p>
#
# | Función en interfaz de tipo Matlab | Método en interfaz orientada a objetos |
# | :--------------------------------- | :------------------------------------- |
# | `plt.xlabel()`                     | `ax.set_xlabel()`                      |
# | `plt.ylabel()`                     | `ax.set_ylabel()`                      |
# | `plt.xlim()`                       | `ax.set_xlim()`                        |
# | `plt.ylim()`                       | `ax.set_ylim()`                        |
# | `plt.title()`                      | `ax.set_title()`                       |
#
# En la interfaz orientada a objetos, para la realización de gráficos, en vez de setear las componentes de nuestra figura una a una, a veces es más útil utilizar la función `ax.set()` para setear todas estas componentes al mismo tiempo:

# %%
# Uso del setting mediante la función plt.axes().
fig = plt.figure(dpi=120)
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 5), ylim=(-2, 2), xlabel='x', ylabel=r'$sen(x)$', title='Un gráfico sencillo');

# %% [markdown]
# ## Gráficos de dispersión.
# Otro tipo especial de gráfico que utilizamos muchísimo en labores comunes de ingeniería corresponde al **gráfico de dispersión**, que en la práctica es un *primo cercano* del gráfico de líneas. En vez de la utilización de puntos unidos mediante segmentos lineales o curvos, aquí dichos puntos son representados mediante círculos, triángulos, rectángulos u otras figuras personalizables a nuestro gusto.
#
# ### Uso de `plt.plot()`.
# Anteriormente utilizamos las funciones `plt.plot()` o `ax.plot()` para generar gráficos de líneas. No obstante, dicha función igualmente puede utilizarse para generar gráficos de dispersión. Basta que especifiquemos el parámetro `marker`, el cual acepta un determinado string que representa un cierto tipo de marcador, pero dejando vacío el parámetro `linestyle`. Por ejemplo, para el caso de marcadores de tipo circulares, bastará con setear `marker="o"`:

# %%
# Generamos algo de data.
x = np.linspace(start=0, stop=4*np.pi, num=50)

# %%
# Construimos un sencillo gráfico de dispersión.
plt.figure(dpi=120)
plt.plot(x, np.cos(x), marker="o", color="black", linestyle="");

# %% [markdown]
# Existen muchos símbolos que permiten dibujar marcadores en un gráfico de dispersión. A continuación, mostraremos varios de ellos:

# %%
# Definimos una semilla aleatoria fija.
rng = np.random.default_rng(42)

# %%
# Mediante un loop, mostraremos varios de estos marcadores.
markers = ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']

plt.figure(figsize=(8, 5), dpi=120)
for marker in markers:
    plt.plot(rng.random(6), rng.random(6), marker, label="marker='{0}'".format(marker))
    plt.legend(loc="upper right")
    plt.xlim(0, 1.5);

# %% [markdown]
# Para ampliar nuestro abanico de posibilidades, estos códigos de caracteres pueden combinarse a fin de generar un plot que muestre un determinado estilo de líneas, puntos y colores para cada gráfico:

# %%
# Combinamos estilos de líneas y marcadores.
plt.figure(dpi=120)
plt.plot(x, np.cos(x), "ob-");

# %% [markdown]
# Los argumentos adicionales para `plt.plot()` permiten especificar un enorme conjunto de opciones para líneas y marcadores:

# %%
# Más opciones de personalización.
plt.figure(dpi=120)
plt.plot(
    x, np.cos(x), '-H', color='darkred', markersize=15, linewidth=4, 
    markerfacecolor='white', markeredgecolor='darkred', markeredgewidth=2
);

# %% [markdown]
# La flexibilidad de `plt.plot()` nos permite disponer de un enorme conjunto de posibles opciones para personalizar nuestros gráficos. Sin embargo, la mayoría de las opciones que permiten ampliar dicha flexibilidad están orientadas a la construcción de gráficos de líneas. Para disponer de más opciones para gráficos de dispersión, es mejor utilizar la función `plt.scatter()`.
#
# ### Uso de `plt.scatter()`.
# La principal diferencia entre `plt.plot()` y `plt.scatter()`, es que la función `plt.scatter()` puede ser utilizada para crear gráficos de dispersión donde las propiedades de cada uno de los puntos que conforman el gráfico (tamaño, color de relleno, color del contorno, etc.) pueden ser controladas individualmente o definidas en función de la misma data. De esta manera, en un gráfico bidimensional (es decir, con dos ejes de graficación), podemos representar hasta cuatro dimensiones de información: Coordenadas de los puntos, color asociado a cada punto y el tamaño relativo de cada uno.
#
# Partamos creando algo de data para ejemplificar lo anterior:

# %%
# Creamos cuatro arreglos unidimensionales para ejemplificar la creación de gráficos de
# dispersión.
x = rng.random(size=100)
y = rng.normal(loc=8, scale=3, size=100)
z = rng.laplace(size=100)
w = x - y**2 + z**3

# %% [markdown]
# La función `plt.scatter()` dispone de varios argumentos asociados a la creación de gráficos de dispersión. Los dos que son obligatorios son `x` e `y`, que corresponden a las dimensiones espaciales de la data a visualizar. Por otro lado, el parámetro `c` nos permite especificar un arreglo unidimensional que detalle como varía el color de cada punto en relación al valor de dicho. Es decir, añade una tercera dimensión a la visualización que estamos construyendo. Para ello, debemos además hacer uso de un determinado **mapa de color** que permita entender sus niveles de variación en magnitud y dirección.
#
# Aún no entraremos en detalles en relación a los mapas de colores, porque por supuesto no es *llegar y utilizar* cualquiera. **Matplotlib** dispone de varios de estos esquemas, codificados mediante un nombre particular, y que suelen usarse por medio del parámetro `cmap`. Por ejemplo, `viridis` hace referencia a un mapa de color de tipo **perceptualmente uniforme y secuencial**, que parte desde un color morado muy oscuro, y termina en un color amarillo claro:

# %%
# Añadimos una tercera dimensión a un gráfico de dispersión por medio de un mapa de colores.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis");

# %% [markdown]
# Para añadir una barra de color que referencie los valores y el color asingado a cada valor de la variable asignada al parámetro `c`, podemos hacer uso de la función `plt.colorbar()`. Dicha función acepta una serie de parámetros para especificar varias características de la misma. Un ejemplo es `label`, que permite establecer el nombre de la variable asociada al parámetro `c`:

# %%
# Añadimos de una barra de color.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$");

# %% [markdown]
# Podemos observar que, por defecto, la posición y orientación de la barra de color es tal que ésta se encuentra a la derecha del gráfico y es vertical. Podemos cambiar estos valores haciendo uso de los parámetros `location`, que acepta los valores `left`, `right`, `top` y `bottom`, y `orientation`, que acepta los valores `vertical` y `horizontal`:

# %%
# Barra de color horizontal, en la parte superior del gráfico.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$", orientation="horizontal", location="top");

# Barra de color horizontal, en la parte inferior del gráfico.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$", orientation="horizontal", location="bottom");

# Barra de color vertical, en el lado izquierdo del gráfico.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$", orientation="vertical", location="left");

# %% [markdown]
# Observamos que la posición de una barra de color puede perfectamente alterar las posiciones que utilizan los elementos en un gráfico. Por ejemplo, si seteamos el título de nuestro gráfico cuando posicionamos la barra de color en su parte superior, ambos elementos se superpondrán:

# %%
# Superposición de título y barra de color.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$", orientation="horizontal", location="top")
plt.title("Título del gráfico");

# %% [markdown]
# Una solución para este problema puede ser la utilización del parámetro `pad` en la funciòn `plt.title()`, y que permite separar el título del panel que es utilizado por el gráfico. Dicho parámetro corresponde a un número entero que especifica cuantas unidades separamos el título de dicho panel:

# %%
# Superposición de título y barra de color.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$", orientation="horizontal", location="top")
plt.title("Título del gráfico", pad=70);

# %% [markdown]
# La cuarta dimensión de información que podemos controlar en un gráfico de dispersión se corresponde con el tamaño de los puntos graficados. Para ello podemos usar el parámetro `s` en la función `plt.scatter()`, que acepta igualmente un arreglo unidimensional que contiene los valores que son representados por los tamaños de estos puntos:

# %%
# Control del tamaño de los puntos en el gráfico.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, s=50*z, cmap="viridis")
plt.colorbar(label=r"Valor de la variable $c$");

# %% [markdown]
# Notemos que hemos multiplicado los valores del arreglo `z` por 50. La razón de aquello es que tales valores son pequeños y pasan desapercibidos si no los amplificamos.
#
# Por cierto, si alteramos los tamaños de los puntos, es probable que los puntos más grandes obstruyan la visión de aquellos que son más pequeños. Podemos controlar la **transparencia** de los puntos en el gráfico mediante el uso del parámetro `alpha`, que corresponde a un número de punto flotante entre 0 y 1, y que mientras más cercano a 0, hará que los puntos se muestren más y más translúcidos:

# %%
# Control de la transparencia de los puntos en el gráfico.
plt.figure(dpi=120)
plt.scatter(x=x, y=y, c=w, s=50*z, cmap="viridis", alpha=0.3)
plt.colorbar(label=r"Valor de la variable $c$");

# %% [markdown]
# Ya hablaremos más adelante acerca de cómo elegir un mapa de color adecuado para nuestros gráficos, y veremos que dicha decisión no es tan sencilla como cabría esperar.
#
# ## Gráficos de área apilada.
# Los gráficos de área apilada corresponden a visualizaciones que permiten observar la evolución de una variable numérica para varios grupos, dentro de una determinada proporción, en un conjunto de datos. Cada grupo se muestra en pantalla por encima del grupo anterior, permitiendo una lectura (ojalá sencilla) de la evolución simultánea de todos los grupos en total. En **Matplotlib**, este tipo de gráfico puede construirse mediante el uso de la función `plt.stackplot()`.
#
# La función `plt.stackplot()` acepta varios argumentos. En primer lugar, necesitamos de un arreglo unidimensional ordenado para mostrar la evolución de las variables correspondientes en un período de tiempo determinado. En general, este primer arreglo suele consistir de una secuencia ordenada de valores, ya sea enteros, de punto flotante, o incluso fechas o períodos de tiempo. Luego, necesitamos definir un total de $n$ arreglos unidimensionales que se correspondan con los valores que toman cada una de las variables para un determinado valor del primer arreglo. Por esta razón, cada arreglo involucrado en el gráfico debe consistir de la misma cantidad de observaciones.
#
# Ejemplifiquemos lo anterior construyendo algo de data:

# %%
# Construimos algo de data aleatoria.
x = np.arange(start=0, stop=100, step=1)
y1 = np.random.default_rng(10).integers(low=0, high=100, size=100)
y2 = np.random.default_rng(20).integers(low=0, high=100, size=100)
y3 = np.random.default_rng(30).integers(low=0, high=100, size=100)

# %%
# Construcción del gráfico de área.
plt.figure(dpi=120, figsize=(10, 5))
plt.stackplot(x, y1, y2, y3, labels=["y1", "y2", "y3"])
plt.legend();

# %% [markdown]
# El gráfico anterior es poco claro, ya que es más apto para mostrar evoluciones simultáneas de variables que están relacionadas conforme alguna proporción. Supongamos pues que `y1`, `y2` e `y3` efectivamente son tres variables para las cuales cada observación hace referencia a una determinada proporción. Por lo tanto, podemos normalizarlas, de manera tal que cada una de las filas correspondientes tenga una suma igual al 100%. Para ello, haremos uso de la librería **Pandas**:

# %%
import pandas as pd

# %%
# Llevamos toda nuestra data a un DataFrame.
data = pd.DataFrame(data={"y1": y1, "y2": y2, "y3": y3})

# %%
# Normalizamos esta data asumiendo que es proporcional por observaciones.
data_perc = data.divide(data.sum(axis=1), axis=0)

# %% [markdown]
# Y ahora sí un gráfico de área será apto para mostrar las evoluciones simultáneas de estas variables:

# %%
# Construcción del gráfico de área apilada.
plt.figure(dpi=120, figsize=(10, 5))
plt.stackplot(
    data.index, data_perc["y1"], data_perc["y2"], data_perc["y3"], labels=["y1", "y2", "y3"]
)
plt.legend();

# %% [markdown]
# ¡Mucho mejor!
#
# **Ejemplo 2.1: Evolución de la mineralogía entrante a una planta concentradora:** Una aplicación interesante relativa a los gráficos de áreas corresponde a la visualización de las proporciones de mineral en *base sulfuro* que entran a una planta concentradora. Si bien estamos acostumbrados a hablar de leyes de cobre al referirnos a la *calidad* del mineral, la verdad es que dichom *cobre* está constituido por un conjunto de varios minerales cuyos porcentajes en masa de cobre es altamente variable. Debido a que en una planta concentradora se procesan sulfuros de cobre, estamos particularmente interesados en entender cuál es la distribución porcentual de minerales de tipo sulfuro que entra a una planta, a fin de conocer las potenciales dificultades que existirán en los correspondientes circuitos de flotación, ya que no todos los sulfuros de cobre presentan la misma susceptibilidad de ser extraídos ni tampoco el mismo tamaño de liberación.
#
# Vamos a comprobar cómo un gráfico de área nos permite observar la evolución temporal de la mineralogía entrante a una planta concentradora en un año de operación, con granularidad diaria. Partiremos accediendo a esta data, la que se encuentra almacenada en el archivo `ore_proportions.xlsx`, en la carpeta `datasets`:

# %%
# Cargamos la data relativa a la mineralogía.
data = pd.read_excel("datasets/ore_proportions.xlsx", engine="openpyxl")

# %%
# Mostramos las primeras 5 filas de esta data.
data.head()
# Out:
#        Fecha  Produccion   Ley CuT     Pirita    Bornita  Calcosina  \
# 0 2018-01-01  103.316365  0.929872  20.756219  52.094036   2.196403
# 1 2018-01-02   81.703672  0.538954   2.584462  49.014270   9.112427
# 2 2018-01-03   83.492120  0.376274  20.058862  36.928306   5.486942
# 3 2018-01-04   55.360567  0.666239  24.588121  27.754243   1.915044
# 4 2018-01-05   46.831650  1.303536  21.933098   9.226822   6.608509
#
#    Calcopirita  Digenita  Covelina  Galena  Blenda  Arsenopirita
# 0    18.234576       0.0  6.718766     0.0       0             0
# 1    30.477345       0.0  8.811496     0.0       0             0
# 2    27.611014       0.0  9.914877     0.0       0             0
# 3    37.859003       0.0  7.883589     0.0       0             0
# 4    57.705830       0.0  4.525740     0.0       0             0

# %% [markdown]
# Claramente, esta data está referida a un día por cada observación. Por esta razón, es buena idea indexar este DataFrame con respecto al tiempo, definido por la columna `"Fecha"`:

# %%
# Seteamos esta data conforme las correspondientes fechas, pasándolas a formato adecuado.
data["Fecha"] = pd.to_datetime(data["Fecha"])
data.set_index("Fecha", inplace=True)

# %% [markdown]
# Partiremos construyendo un gráfico diario. Esto es impráctico, puesto que no resultará adecuado para mostrar las evoluciones de cada proporción de sulfuros entrante a la planta. Pero en cualquier caso, dejaremos el código necesario para construir esta visualización. Observemos que la leyenda de este gráfico se emplaza a la derecha del mismo, fuera del panel donde se grafica la data. Para lograr ésto, usamos el parámetro `bbox_to_anchor` en la función `plt.legend()`, y del que daremos detalles cuando abordemos la personalización de elementos en umn gráfico:

# %%
# Visualizamos la variabilidad simultánea de las proporciones de minerales.
plt.figure(figsize=(10, 5), dpi=120)
colors = ["gold", "purple", "steelblue", "yellow", "gray", "skyblue", "black", "silver", "green"]
plt.stackplot(
    data.index, data["Pirita"], data["Bornita"], data["Calcosina"], 
    data["Calcopirita"], data["Digenita"], data["Covelina"],
    data["Galena"], data["Blenda"], data["Arsenopirita"],
    labels=data.loc[:, "Pirita":].columns.tolist(),
    colors=colors
)
plt.title(
    "Evolución de mineralogías entrantes a planta (frec. diaria, 2019)", 
    fontsize=12, fontweight="bold", pad=10
)
plt.xlabel("Fecha", fontsize=10, labelpad=10)
plt.ylabel("Proporción (%)", fontsize=10, labelpad=5)
plt.legend(fontsize=6, bbox_to_anchor=(1.12, 1.01));

# %% [markdown]
# Dada la alta variabilidad de estas proporciones, podemos optar por hacer un remuestreo semanal y mensual de esta data, usando el método `resample()`:

# %%
# Remuestreo de los datos de mineralogía con frecuencia semanal y mensual.
grades_weekly = data.loc[:, "Pirita":].resample("W").mean()
grades_monthly = data.loc[:, "Pirita":].resample("M").mean()

# %%
# Gráfico con promedios semanales.
plt.figure(figsize=(10, 5), dpi=120)
colors = ["gold", "purple", "steelblue", "yellow", "gray", "skyblue", "black", "silver", "green"]
plt.stackplot(
    grades_weekly.index, grades_weekly["Pirita"], grades_weekly["Bornita"], grades_weekly["Calcosina"], 
    grades_weekly["Calcopirita"], grades_weekly["Digenita"], grades_weekly["Covelina"],
    grades_weekly["Galena"], grades_weekly["Blenda"], grades_weekly["Arsenopirita"],
    labels=grades_weekly.loc[:, "Pirita":].columns.tolist(),
    colors=colors
)
plt.title(
    "Evolución de mineralogías entrantes a planta (frec. semanal, 2019)", 
    fontsize=12, fontweight="bold", pad=10
)
plt.xlabel("Fecha", fontsize=10, labelpad=10)
plt.ylabel("Proporción (%)", fontsize=10, labelpad=5)
plt.legend(fontsize=6, bbox_to_anchor=(1.12, 1.01));

# %% [markdown]
# Observemos que hay períodos sin data, lo que probablemente implica extensiones de tiempo donde la planta se encontraba fuera de servicio. Volvemos a repetir el gráfico anterior, conforme una frecuencia mensual:

# %%
# Gráfico con promedios mensuales.
plt.figure(figsize=(10, 5), dpi=120)
colors = ["gold", "purple", "steelblue", "yellow", "gray", "skyblue", "black", "silver", "green"]
plt.stackplot(
    grades_monthly.index, grades_monthly["Pirita"], grades_monthly["Bornita"], grades_monthly["Calcosina"], 
    grades_monthly["Calcopirita"], grades_monthly["Digenita"], grades_monthly["Covelina"],
    grades_monthly["Galena"], grades_monthly["Blenda"], grades_monthly["Arsenopirita"],
    labels=grades_monthly.loc[:, "Pirita":].columns.tolist(),
    colors=colors
)
plt.title(
    "Evolución de mineralogías entrantes a planta (frec. mensual, 2019)", 
    fontsize=12, fontweight="bold", pad=10
)
plt.xlabel("Fecha", fontsize=10, labelpad=10)
plt.ylabel("Proporción (%)", fontsize=10, labelpad=5)
plt.legend(fontsize=6, bbox_to_anchor=(1.12, 1.01));

# %% [markdown]
# Y así está mucho mejor. Observamos que la mena principal de esta operación corresponde a la calcopirita, seguida de la bornita. Esto puede resultar un problema, la que ambos minerales pueden *competir* en términos de su reactividad en el proceso de flotación. Además, se observan elevadas proporciones de pirita en todo el año (en general, del 20% o más), lo que podría significar niveles importantes de pH en la pulpa entrante a flotación debido a la ley de fierro. ◼
#
# ## Gráficos de contorno.
# A resulta útil visualizar data tridimensional en dos dimensiones usando contornos o regiones codificadas mediante colores, para lo cual **Matplotlib** dispone de varias funciones, destacando entre ellas `plt.contour()` y `plt.contourf()`. Estas funciones son importantes debido a que permiten representar data en tres dimensiones, aprovechando una visualización en dos dimensiones, por medio del uso de mapas de color.
#
# Vamos a ejemplificar el uso de estas funciones de graficación definiendo a su vez una función del tipo $z=f(x,y)$. En este ejemplo práctico, haremos uso de la función $f\left( x,y\right)  =\cos^{3} \left( x\right)  -\mathrm{s} \mathrm{e} \mathrm{n} \left( 3xy\right)  \cos \left( y\right)$:

# %%
# La función con la cual vamos a trabajar.
def f(x, y):
    return np.cos(x)**3 - np.sin(3*x*y)*np.cos(y)

# %% [markdown]
# Un gráfico de contorno puede construirse mediante la función `plt.contour()`. Dicha función toma tres argumentos: Una grilla de valores `x`, una grilla de valores `y`, y una grilla de valores `z`. Los valores `x` e `y` representan posiciones en el gráfico, y los valores de `z` representarán los valores de la correspondiente función de ambas variables. Para construir estos arreglos, como vimos en la primera sección de la asignatura, podemos hacer uso de la función de la función `np.meshgrid()`:

# %%
# Definimos los arreglos base sobre los que construiremos la grilla.
x = np.linspace(0, 6, 100)
y = np.linspace(0, 6, 100)

# %%
# Construimos la grilla.
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# Y ahora ya podemos visualizar los valores de `Z` mediante la función `plt.contour()`. Para ello, como en el caso de la función `plt.scatter()`, haremos uso de un mapa de color mediante el parámetro `cmap` (en este caso, usaremos el mapa `Spectral`, que es uno de tipo divergente. Otro parámetro importante es `levels`, el cual nos permite definir el número de lineas de contorno a mostrar el gráfico:

# %%
# Gráfico de contorno.
plt.figure(figsize=(10, 7), dpi=120)
plt.contour(X, Y, Z, levels=20, cmap="Spectral");

# %% [markdown]
# En el gráfico anterior, hemos escogido el mapa de color `RdGy` (abreviación de *Red-Gray*), el cual es apropiado para data que se encuentra centrada respecto de algún valor representativo (como es el caso de las funciones trigonométricas, o data normalmente distribuida). En cualquier caso, nuestro gráfico nos permite visualizar claramente la variación del valor de `Z` en función de las variables independientes `X` e `Y`. Sin embargo, el espacio entre las líneas de contorno puede llegar a ser un elemento distractor para cualquier *cliente* que observe esta forma de presentar la data. Podemos rellenar dicho espacio usando los colores del mapa de color de nuestra elección mediante la función `plt.contourf()`, cuya sintaxis esencialmente la misma que la de la función `plt.contour()`. Adicionalmente, añadiremos una barra que especifique el significado del mapa de color mediante la función `plt.colorbar()`, lo que nos permitirá identificar inmediatamente qué valores, conforme el correspondiente color, representan valles y crestas en esta visualización:

# %%
# Gráfico de contorno con relleno.
plt.figure(figsize=(10, 7), dpi=120)
plt.contourf(X, Y, Z, levels=50, cmap="Spectral")
plt.colorbar();

# %% [markdown]
# Finalmente, puede resultar útil combinar contornos y curvas de nivel, a fin de aumentar el nivel de especificidad de la información visualizada. Para eso, podemos usar las funciones `plt.clabel()` (para rotular los contornos) y la función `plt.imshow()`, que nos permite visualizar cualquier imagen transformándola previamente a un arreglo de **Numpy**, y que abordaremos en detalle más adelante:

# %%
# Creamos una visualización que combina contornos rellenos y curvas de nivel.
plt.figure(figsize=(10, 7), dpi=120)
contours = plt.contour(X, Y, Z, levels=5, colors='black')
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar();
